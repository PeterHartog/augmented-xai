# %%
from rdkit import Chem
import pandas as pd

# %%
alerts = pd.read_csv("data/structural_alerts.csv")
examples = pd.DataFrame([None]*len(alerts), columns=["example"])

# %%
alerts.head()
# Out:
#       toxicophore name      smarts  \
# 0  specific arom nitro    O=N(~O)a
# 1  specific arom amine      a[NH2]
# 2     aromatic nitroso   a[N;X2]=O
# 3        alkyl nitrite  CO[N;X2]=O
# 4          nitrosamine   N[N;X2]=O
#
#                                      excluded_smarts
# 0  O=N(O)c[$(aS(=O)=O),$(aaS(=O)=O),$(aaaS(=O)=O)...
# 1  [NH2]a[$(a[$(C((F)F)F),$(S(=O)=O),$(C(=O)O)]),...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
examples.head()
# Out:
#   example
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
id = 0
examples['example'].iloc[id] = "C1(=CC=CC=C1)[N+]([O-])=O"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((8, 6, 7, 0),)

# %%
id = 1
examples['example'].iloc[id] = "C1(=CC=CC=C1)N"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((0, 6),)

# %%
id = 2
examples['example'].iloc[id] = "C1(=CC=CC=C1)N=O"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((0, 6, 7),)

# %%
id = 3
examples['example'].iloc[id] = "[N](=O)OC"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((3, 2, 0, 1),)

# %%
id = 4
examples['example'].iloc[id] = "C[N][N](=O)"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((1, 2, 3),)

# %%
id = 5
examples['example'].iloc[id] = "C1CO1"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((2, 1, 0),)

# %%
id = 6
examples['example'].iloc[id] = "C1C[NH]1"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((0, 2, 1),)

# %%
id = 7
examples['example'].iloc[id] = "N=[N+]=[N-]"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((0, 1, 2),)

# %%
id = 8
examples['example'].iloc[id] = "C=[N+]=[N-]"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((0, 1, 2),)

# %%
id = 9
examples['example'].iloc[id] = "N(=N)[N]"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((1, 0, 2),)

# %%
id = 10
examples['example'].iloc[id] = "C1(=CC=CC=C1)[N]=[N]C2=CC=CC=C2"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((0, 6, 7, 8),)

# %%
id = 11
examples['example'].iloc[id] = "CN[NH2]"
alerts['smarts'].iloc[id] = "[N,O,P,S][N,O,P,S]"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((1, 2),)

# %%
id = 12
examples['example'].iloc[id] = "C1(=CC=CC=C1)NO"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((7, 6),)

# %%
id = 13
examples['example'].iloc[id] = "CO[OH]"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((2, 1),)

# %%
id = 14
examples['example'].iloc[id] = "C=N[OH]"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((2, 1, 0),)

# %%
id = 15
examples['example'].iloc[id] = "C1(=CC=CC=C1)[O][O]C2=CC=CC=C2"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((0, 6, 7, 8),)

# %%
id = 16
examples['example'].iloc[id] = "CCNNCC"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((1, 2, 3, 4),)

# %%
id = 17
examples['example'].iloc[id] = "C1(=CC=CC=C1)[N][OH]"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((7, 6, 0),)

# %%
id = 18
examples['example'].iloc[id] = "CC[N][OH]"
alerts['smarts'].iloc[id] = "[OH]NC"
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ((3, 2, 1),)

# %%
id = 19
examples['example'].iloc[id] = "C1(=CC=CC=C1)[N][NH2]"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# aromatic hydrazine
# [NH2]Na
# ((7, 6, 0),)

# %%
id = 20
examples['example'].iloc[id] = "CC[N][NH2]"
alerts['smarts'].iloc[id] = "[NH2]NC"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# aliphatic hydrazine
# [NH2]NC
# ((3, 2, 1),)

# %%
id = 21
examples['example'].iloc[id] = "C[N]=[N][OH]"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# diazohydroxyl
# [OH][N;X2]=[N;X2]
# ((3, 2, 1),)

# %%
id = 22
examples['example'].iloc[id] = "CCI"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# aliphatic halide
# [Cl,Br,I]C
# ((2, 1),)

# %%
id = 23
examples['example'].iloc[id] = "CC(=O)I"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# carboxylic acid halide
# [Cl,Br,I]C=O
# ((3, 1, 2),)

# %%
id = 24
examples['example'].iloc[id] = "CNCCI"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# nitrogen or sulphur mustard
# [N,S]!@[C;X4]!@[CH2][Cl,Br,I]
# ((1, 2, 3, 4),)

# %%
id = 25
examples['example'].iloc[id] = "CNCCI"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# aliphatic monohalide
# [Cl,Br,I][C;X4]
# ((4, 3),)

# %%
id = 26
examples['example'].iloc[id] = "SC(Cl)C"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# alpha-chlorothioalkane
# SC[Cl]
# ((0, 1, 2),)

# %%
id = 27
examples['example'].iloc[id] = "OCC(Cl)C"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# beta-halo ethoxy group
# [Cl,Br,I]!@[C;X4]!@[C;X4]O
# ((3, 2, 1, 0),)

# %%
id = 28
examples['example'].iloc[id] = "C(F)(F)=C(Cl)F"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# chloroalkene
# [Cl]C([X1])=C[X1]
# ((4, 3, 5, 0, 1), (4, 3, 5, 0, 2))

# %%
id = 29
examples['example'].iloc[id] = "CC(Cl)F"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# 1-chloroethyl
# [Cl,Br,I][CH][CH3]
# ((2, 1, 0),)

# %%
id = 30
examples['example'].iloc[id] = "CC=CC(Cl)F"
alerts['smarts'].iloc[id] = "[Cl,Br,I]C([F,Cl,Br,I;X1])C=C"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# polyhaloalkene
# [Cl,Br,I]C([F,Cl,Br,I;X1])C=C
# ((4, 3, 5, 2, 1),)

# %%
id = 31
examples['example'].iloc[id] = "CCC(=O)C(Cl)F"
alerts['smarts'].iloc[id] = "[Cl,Br,I]C([F,Cl,Br,I;X1])C(=O)[c,C]"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# polyhalocarbonyl
# [Cl,Br,I]C([F,Cl,Br,I;X1])C(=O)[c,C]
# ((5, 4, 6, 2, 3, 1),)

# %%
id = 32
examples['example'].iloc[id] = "CC1=CC=CC2=C1C=CC3=C2C=CC=C3"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# bay-region in polycyclic aromatic hydrocarbons
# [cH]1[cH]ccc2c1c3c(cc2)cc[cH][cH]3
# ((4, 3, 2, 1, 6, 5, 10, 9, 8, 7, 14, 13, 12, 11),)

# %%
id = 33
examples['example'].iloc[id] = "ClC1=CC=C2C(=C1)C3=C(C=C2)C=CC=C3"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# k-region in polycyclic aromatic hydrocarbons
# [cH]1cccc2c1[cH][cH]c3c2ccc[cH]3
# ((3, 2, 1, 6, 5, 4, 10, 9, 8, 7, 14, 13, 12, 11),)

# %% [markdown]
# Aliphatic ring systems are groups 34-42

# %%
id = 43
examples['example'].iloc[id] = "C(C1=CC=CC=C1)O[S](=O)=O"
alerts['smarts'].iloc[id] = "[C,c]OS(=O)(=O)"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# sulphonate-bonded carbon (alkyl alkane sulphonate or dialkyl sulphate)
# [C,c]OS(=O)(=O)
# ((0, 7, 8, 9, 10),)

# %%
id = 44
examples['example'].iloc[id] = "CN[N+](=O)[O-]"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# aliphatic N-nitro
# O=N(~O)N
# ((3, 2, 4, 1),)

# %%
id = 45
examples['example'].iloc[id] = "C=CC(=O)"
alerts['smarts'].iloc[id] = "O=[CH]C=[C,O]"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# alpha,beta unsaturated aldehyde (including alpha-carbonyl aldehyde)
# O=[CH]C=[C,O]
# ((3, 2, 1, 0),)

# %%
id = 46
examples['example'].iloc[id] = "C[N+]#[N]"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# diazonium
# [N;v4]#N
# ((1, 2),)

# %%
id = 47
examples['example'].iloc[id] = "CC1C(=O)OC1"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# beta-propiolactone
# O=C1CCO1
# ((3, 2, 1, 5, 4),)

# %%
id = 48
examples['example'].iloc[id] = "CC=CO"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# alpha,beta unsaturated alkoxy group
# [CH]=[CH]O
# ((1, 2, 3),)

# %%
id = 49
examples['example'].iloc[id] = "C1(=CC=CC=C1)[NH][NH]C"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# 1-aryl-2-monoalkylhydrazine
# [NH;!R][NH;!R]a
# ((7, 6, 0),)

# %%
id = 50
examples['example'].iloc[id] = "C1(=CC=CC=C1)NC"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# aromatic methylamine
# [CH3][NH]a
# ((7, 6, 0),)

# %%
id = 51
examples['example'].iloc[id] = "C1(=CC=CC=C1)NOC=O"
alerts['smarts'].iloc[id] = "aNOC~O"
print(alerts.iloc[id]["toxicophore name"])
print(alerts.iloc[id].smarts)
m = Chem.MolFromSmiles(examples.iloc[id].example)
p = Chem.MolFromSmarts(alerts.iloc[id].smarts)
print(m.GetSubstructMatches(p))
m
# Out:
# ester derivative of aromatic hydroxylamine (including original specific toxicophore)
# aNOC~O
# ((0, 6, 7, 8, 9),)

# %% [markdown]
# # Save new file

# %%
structural_alerts = pd.concat([alerts, examples], axis=1)
structural_alerts.to_csv("data/updated_structural_alerts.csv", index=False)
structural_alerts.head()
# Out:
#       toxicophore name      smarts  \
# 0  specific arom nitro    O=N(~O)a
# 1  specific arom amine      a[NH2]
# 2     aromatic nitroso   a[N;X2]=O
# 3        alkyl nitrite  CO[N;X2]=O
# 4          nitrosamine   N[N;X2]=O
#
#                                      excluded_smarts  \
# 0  O=N(O)c[$(aS(=O)=O),$(aaS(=O)=O),$(aaaS(=O)=O)...
# 1  [NH2]a[$(a[$(C((F)F)F),$(S(=O)=O),$(C(=O)O)]),...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      example
# 0  C1(=CC=CC=C1)[N+]([O-])=O
# 1             C1(=CC=CC=C1)N
# 2           C1(=CC=CC=C1)N=O
# 3                  [N](=O)OC
# 4                C[N][N](=O)
